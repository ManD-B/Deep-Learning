# %% [markdown]
# # 시계열 예측 문제
# - 사인파형 시계열을 입력으로 다음 스텝의 출력을 예측
# - 3개의 순서열을 입력한 후 출력값이 target과 일치하게 만듦

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
s = np.sin(2 * np.pi * 0.125 * np.arange(20))
plt.plot(s, 'ro-')
plt.xlim(-0.5, 20.5)
plt.ylim(-1.1, 1.1)
plt.show()

# %% [markdown]
# ### 원래의 시계열 벡터를 Toeplitz 행렬 형태로 변환
# #### (대각선 위의 성분들이 같은 정사각 행렬)

# %%
from scipy.linalg import toeplitz
S = np.fliplr(toeplitz(np.r_[s[-1], np.zeros(s.shape[0] - 2)], s[::-1]))
S[:5, :3]
# Out:
# array([[ 0.00000000e+00,  7.07106781e-01,  1.00000000e+00],
#        [ 7.07106781e-01,  1.00000000e+00,  7.07106781e-01],
#        [ 1.00000000e+00,  7.07106781e-01,  1.22464680e-16],
#        [ 7.07106781e-01,  1.22464680e-16, -7.07106781e-01],
#        [ 1.22464680e-16, -7.07106781e-01, -1.00000000e+00]])

# %%
X_train = S[:-1, :3][:, :, np.newaxis]
Y_train = S[:-1, 3]
X_train.shape, Y_train.shape
# Out:
# ((18, 3, 1), (18,))

# %%
X_train[:4]
# Out:
# array([[[ 0.00000000e+00],
#         [ 7.07106781e-01],
#         [ 1.00000000e+00]],
#
#        [[ 7.07106781e-01],
#         [ 1.00000000e+00],
#         [ 7.07106781e-01]],
#
#        [[ 1.00000000e+00],
#         [ 7.07106781e-01],
#         [ 1.22464680e-16]],
#
#        [[ 7.07106781e-01],
#         [ 1.22464680e-16],
#         [-7.07106781e-01]]])

# %%
Y_train[:4]
# Out:
# array([ 7.07106781e-01,  1.22464680e-16, -7.07106781e-01, -1.00000000e+00])

# %%
plt.figure(figsize=(10,6))

plt.subplot(211)
plt.plot([0, 1, 2], X_train[0].flatten(), 'bo-', label="input sequence")
plt.plot([3], Y_train[0], 'ro', label="target")
plt.xlim(-0.5, 4.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.grid()
plt.title("First sample sequence")

plt.subplot(212)
plt.plot([1, 2, 3], X_train[1].flatten(), 'bo-', label="input sequence")
plt.plot([4], Y_train[1], 'ro', label="target")
plt.xlim(-0.5, 4.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.grid()
plt.title("Second sample sequence")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### RNN으로 해결 - SimpleRNN() 사용

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense

seed = 2020
np.random.seed(seed)
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(SimpleRNN(10, input_shape=(3, 1)))
model.add(Dense(1, activation="linear"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 10)                120
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2 = Sequential()
model2.add(SimpleRNN(5, input_shape=(3, 1)))
model2.add(Dense(1, activation="linear"))
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_2 (SimpleRNN)     (None, 5)                 35
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3 = Sequential()
model3.add(SimpleRNN(20, input_shape=(3, 1)))
model3.add(Dense(1, activation="linear"))
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_3 (SimpleRNN)     (None, 20)                440
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 461
# Trainable params: 461
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='sgd')

# %%
model2.compile(loss='mse', optimizer='sgd')

# %%
model3.compile(loss='mse', optimizer='sgd')

# %%
plt.plot(Y_train, 'ro-', label="target")
plt.plot(model.predict(X_train[:, :, :]), 'bs-', label="output")
plt.xlim(-0.5, 20.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.title("Before training")
plt.show()

# %%
plt.plot(Y_train, 'ro-', label="target")
plt.plot(model2.predict(X_train[:, :, :]), 'bs-', label="output")
plt.xlim(-0.5, 20.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.title("Before training")
plt.show()

# %%
plt.plot(Y_train, 'ro-', label="target")
plt.plot(model3.predict(X_train[:, :, :]), 'bs-', label="output")
plt.xlim(-0.5, 20.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.title("Before training")
plt.show()

# %%
history = model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3665
# Epoch 2/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.3462
# Epoch 3/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.3269
# Epoch 4/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.3087
# Epoch 5/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2915
# Epoch 6/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.2752
# Epoch 7/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2598
# Epoch 8/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.2451
# Epoch 9/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2313
# Epoch 10/100
# 18/18 [==============================] - 0s 0us/step - loss: 0.2182
# Epoch 11/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2058
# Epoch 12/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1940
# Epoch 13/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1829
# Epoch 14/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.1723
# Epoch 15/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1624
# Epoch 16/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1529
# Epoch 17/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1440
# Epoch 18/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.1356
# Epoch 19/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1276
# Epoch 20/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1200
# Epoch 21/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1129
# Epoch 22/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1062
# Epoch 23/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0998
# Epoch 24/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0938
# Epoch 25/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0882
# Epoch 26/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0829
# Epoch 27/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0778
# Epoch 28/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0731
# Epoch 29/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0686
# Epoch 30/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0644
# Epoch 31/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0605
# Epoch 32/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0567
# Epoch 33/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0532
# Epoch 34/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0499
# Epoch 35/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0468
# Epoch 36/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0439
# Epoch 37/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0412
# Epoch 38/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0386
# Epoch 39/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0362
# Epoch 40/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0339
# Epoch 41/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0318
# Epoch 42/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0298
# Epoch 43/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0279
# Epoch 44/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0261
# Epoch 45/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0245
# Epoch 46/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0229
# Epoch 47/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0215
# Epoch 48/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0201
# Epoch 49/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0188
# Epoch 50/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0176
# Epoch 51/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0165
# Epoch 52/100
# 18/18 [==============================] - 0s 112us/step - loss: 0.0155
# Epoch 53/100
# 18/18 [==============================] - 0s 110us/step - loss: 0.0145
# Epoch 54/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.0135
# Epoch 55/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0127
# Epoch 56/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0119
# Epoch 57/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0111
# Epoch 58/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0104
# Epoch 59/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0098
# Epoch 60/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0091
# Epoch 61/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0086
# Epoch 62/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0080
# Epoch 63/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0075
# Epoch 64/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.0071
# Epoch 65/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0066
# Epoch 66/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0062
# Epoch 67/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0058
# Epoch 68/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0055
# Epoch 69/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0051
# Epoch 70/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0048
# Epoch 71/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0045
# Epoch 72/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0042
# Epoch 73/100
# 18/18 [==============================] - 0s 54us/step - loss: 0.0040
# Epoch 74/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0037
# Epoch 75/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0035
# Epoch 76/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0033
# Epoch 77/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0031
# Epoch 78/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0029
# Epoch 79/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0028
# Epoch 80/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0026
# Epoch 81/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0025
# Epoch 82/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0023
# Epoch 83/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0022
# Epoch 84/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0021
# Epoch 85/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0020
# Epoch 86/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0019
# Epoch 87/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0018
# Epoch 88/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0017
# Epoch 89/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0016
# Epoch 90/100
# 18/18 [==============================] - 0s 110us/step - loss: 0.0015
# Epoch 91/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0014
# Epoch 92/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0014
# Epoch 93/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0013
# Epoch 94/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0012
# Epoch 95/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0012
# Epoch 96/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0011
# Epoch 97/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0011
# Epoch 98/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0010
# Epoch 99/100
# 18/18 [==============================] - 0s 55us/step - loss: 9.9068e-04
# Epoch 100/100
# 18/18 [==============================] - 0s 55us/step - loss: 9.5121e-04

# %%
history2 = model2.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9735
# Epoch 2/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.8720
# Epoch 3/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.7866
# Epoch 4/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.7144
# Epoch 5/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.6534
# Epoch 6/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.6015
# Epoch 7/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.5573
# Epoch 8/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.5194
# Epoch 9/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.4867
# Epoch 10/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.4584
# Epoch 11/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.4338
# Epoch 12/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.4121
# Epoch 13/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.3930
# Epoch 14/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.3760
# Epoch 15/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.3607
# Epoch 16/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.3469
# Epoch 17/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.3343
# Epoch 18/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.3227
# Epoch 19/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.3120
# Epoch 20/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.3021
# Epoch 21/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2927
# Epoch 22/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2839
# Epoch 23/100
# 18/18 [==============================] - 0s 54us/step - loss: 0.2756
# Epoch 24/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2677
# Epoch 25/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.2601
# Epoch 26/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2528
# Epoch 27/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2458
# Epoch 28/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2390
# Epoch 29/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2325
# Epoch 30/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2261
# Epoch 31/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2200
# Epoch 32/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2140
# Epoch 33/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.2082
# Epoch 34/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.2025
# Epoch 35/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1970
# Epoch 36/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1916
# Epoch 37/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1863
# Epoch 38/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.1812
# Epoch 39/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.1762
# Epoch 40/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.1713
# Epoch 41/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1665
# Epoch 42/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1619
# Epoch 43/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.1573
# Epoch 44/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1529
# Epoch 45/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1486
# Epoch 46/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.1444
# Epoch 47/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1403
# Epoch 48/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.1363
# Epoch 49/100
# 18/18 [==============================] - 0s 57us/step - loss: 0.1324
# Epoch 50/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1286
# Epoch 51/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1248
# Epoch 52/100
# 18/18 [==============================] - 0s 110us/step - loss: 0.1212
# Epoch 53/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1177
# Epoch 54/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1143
# Epoch 55/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1110
# Epoch 56/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1078
# Epoch 57/100
# 18/18 [==============================] - 0s 54us/step - loss: 0.1046
# Epoch 58/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1015
# Epoch 59/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0986
# Epoch 60/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.0957
# Epoch 61/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0929
# Epoch 62/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0902
# Epoch 63/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0875
# Epoch 64/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0850
# Epoch 65/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0825
# Epoch 66/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0801
# Epoch 67/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0777
# Epoch 68/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0754
# Epoch 69/100
# 18/18 [==============================] - 0s 54us/step - loss: 0.0733
# Epoch 70/100
# 18/18 [==============================] - 0s 112us/step - loss: 0.0711
# Epoch 71/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0691
# Epoch 72/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0671
# Epoch 73/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0651
# Epoch 74/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0633
# Epoch 75/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0614
# Epoch 76/100
# 18/18 [==============================] - 0s 57us/step - loss: 0.0597
# Epoch 77/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0580
# Epoch 78/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0564
# Epoch 79/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0548
# Epoch 80/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0533
# Epoch 81/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0518
# Epoch 82/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0503
# Epoch 83/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.0490
# Epoch 84/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0476
# Epoch 85/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0463
# Epoch 86/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0451
# Epoch 87/100
# 18/18 [==============================] - 0s 54us/step - loss: 0.0439
# Epoch 88/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.0427
# Epoch 89/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0416
# Epoch 90/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0405
# Epoch 91/100
# 18/18 [==============================] - 0s 57us/step - loss: 0.0395
# Epoch 92/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0385
# Epoch 93/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0375
# Epoch 94/100
# 18/18 [==============================] - 0s 54us/step - loss: 0.0366
# Epoch 95/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0357
# Epoch 96/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0348
# Epoch 97/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0340
# Epoch 98/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0332
# Epoch 99/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0324
# Epoch 100/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0317

# %%
history3 = model3.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7677
# Epoch 2/100
# 18/18 [==============================] - 0s 0us/step - loss: 0.7060
# Epoch 3/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.6503
# Epoch 4/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.5999
# Epoch 5/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.5540
# Epoch 6/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.5122
# Epoch 7/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.4740
# Epoch 8/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.4389
# Epoch 9/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.4067
# Epoch 10/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.3770
# Epoch 11/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.3496
# Epoch 12/100
# 18/18 [==============================] - 0s 110us/step - loss: 0.3243
# Epoch 13/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.3009
# Epoch 14/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2792
# Epoch 15/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2591
# Epoch 16/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2405
# Epoch 17/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.2233
# Epoch 18/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.2072
# Epoch 19/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1923
# Epoch 20/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1785
# Epoch 21/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1656
# Epoch 22/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1537
# Epoch 23/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1426
# Epoch 24/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1323
# Epoch 25/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1227
# Epoch 26/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1138
# Epoch 27/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.1055
# Epoch 28/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0978
# Epoch 29/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0907
# Epoch 30/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0841
# Epoch 31/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0779
# Epoch 32/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0722
# Epoch 33/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0669
# Epoch 34/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0620
# Epoch 35/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0574
# Epoch 36/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0531
# Epoch 37/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0492
# Epoch 38/100
# 18/18 [==============================] - 0s 57us/step - loss: 0.0456
# Epoch 39/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0422
# Epoch 40/100
# 18/18 [==============================] - 0s 54us/step - loss: 0.0390
# Epoch 41/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0361
# Epoch 42/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0335
# Epoch 43/100
# 18/18 [==============================] - 0s 54us/step - loss: 0.0310
# Epoch 44/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0287
# Epoch 45/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0265
# Epoch 46/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0246
# Epoch 47/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0227
# Epoch 48/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0210
# Epoch 49/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0195
# Epoch 50/100
# 18/18 [==============================] - 0s 110us/step - loss: 0.0180
# Epoch 51/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0167
# Epoch 52/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0154
# Epoch 53/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0143
# Epoch 54/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0132
# Epoch 55/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0123
# Epoch 56/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0114
# Epoch 57/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0105
# Epoch 58/100
# 18/18 [==============================] - 0s 110us/step - loss: 0.0098
# Epoch 59/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0090
# Epoch 60/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0084
# Epoch 61/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0078
# Epoch 62/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0072
# Epoch 63/100
# 18/18 [==============================] - 0s 57us/step - loss: 0.0067
# Epoch 64/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0062
# Epoch 65/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0058
# Epoch 66/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0054
# Epoch 67/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0050
# Epoch 68/100
# 18/18 [==============================] - 0s 56us/step - loss: 0.0047
# Epoch 69/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0043
# Epoch 70/100
# 18/18 [==============================] - 0s 54us/step - loss: 0.0041
# Epoch 71/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0038
# Epoch 72/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0035
# Epoch 73/100
# 18/18 [==============================] - 0s 57us/step - loss: 0.0033
# Epoch 74/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0031
# Epoch 75/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0029
# Epoch 76/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0027
# Epoch 77/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0025
# Epoch 78/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0024
# Epoch 79/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0023
# Epoch 80/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0021
# Epoch 81/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0020
# Epoch 82/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0019
# Epoch 83/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0018
# Epoch 84/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0017
# Epoch 85/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0016
# Epoch 86/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0015
# Epoch 87/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0015
# Epoch 88/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0014
# Epoch 89/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0013
# Epoch 90/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0013
# Epoch 91/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0012
# Epoch 92/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0012
# Epoch 93/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0011
# Epoch 94/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0011
# Epoch 95/100
# 18/18 [==============================] - 0s 111us/step - loss: 0.0010
# Epoch 96/100
# 18/18 [==============================] - 0s 55us/step - loss: 0.0010
# Epoch 97/100
# 18/18 [==============================] - 0s 55us/step - loss: 9.7471e-04
# Epoch 98/100
# 18/18 [==============================] - 0s 55us/step - loss: 9.4495e-04
# Epoch 99/100
# 18/18 [==============================] - 0s 55us/step - loss: 9.1753e-04
# Epoch 100/100
# 18/18 [==============================] - 0s 57us/step - loss: 8.9227e-04

# %% [markdown]
# ### 결과 확인

# %%
plt.plot(history.history["loss"])
plt.title("Loss")
plt.show()

# %%
plt.plot(history2.history["loss"])
plt.title("Loss")
plt.show()

# %%
plt.plot(history3.history["loss"])
plt.title("Loss")
plt.show()

# %%
plt.plot(Y_train, 'ro-', label="target")
plt.plot(model.predict(X_train[:, :, :]), 'bs-', label="output")
plt.xlim(-0.5, 20.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.title("After training")
plt.show()

# %%
plt.plot(Y_train, 'ro-', label="target")
plt.plot(model2.predict(X_train[:, :, :]), 'bs-', label="output")
plt.xlim(-0.5, 20.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.title("After training")
plt.show()

# %%
plt.plot(Y_train, 'ro-', label="target")
plt.plot(model3.predict(X_train[:, :, :]), 'bs-', label="output")
plt.xlim(-0.5, 20.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.title("After training")
plt.show()

# %%
# 입력에 대한 weights
model.weights[0]
# Out:
# <tf.Variable 'simple_rnn_1/kernel:0' shape=(1, 10) dtype=float32, numpy=
# array([[ 0.31113496, -0.5350309 , -0.17106609, -0.35133094, -0.5814482 ,
#          0.41476998,  0.3126239 , -0.0475806 , -0.43024546, -0.25811163]],
#       dtype=float32)>

# %%
# 유닛에 대한 weights
model.weights[1]
# Out:
# <tf.Variable 'simple_rnn_1/recurrent_kernel:0' shape=(10, 10) dtype=float32, numpy=
# array([[-0.29332197, -0.02267686, -0.45017317, -0.06278142,  0.38479894,
#         -0.499793  , -0.3209854 , -0.01187507,  0.20133896, -0.40036467],
#        [ 0.40109155, -0.18653043, -0.5243529 ,  0.14630622,  0.17135185,
#          0.6216256 , -0.09945873, -0.1311867 , -0.1243751 , -0.27204865],
#        [-0.19665305, -0.1720411 ,  0.36357763,  0.30392343, -0.11612891,
#          0.28862143,  0.17779362,  0.09661648,  0.46272904, -0.6623994 ],
#        [-0.07720977,  0.48544714, -0.09584784, -0.17508772, -0.3179628 ,
#          0.290148  , -0.6028821 ,  0.2716179 ,  0.3168384 ,  0.10557304],
#        [-0.18821228, -0.29480058, -0.22804125,  0.69704586, -0.02637194,
#          0.12681808, -0.02304817, -0.23566832,  0.49735203,  0.49945664],
#        [ 0.08335648,  0.07700554,  0.4568554 ,  0.2812518 ,  0.6416771 ,
#         -0.04727153, -0.4047447 ,  0.3167393 , -0.29454532,  0.05634448],
#        [ 0.35910776,  0.3381388 ,  0.3533085 , -0.13108014,  0.28044263,
#         -0.06518581, -0.1179864 , -0.64458925,  0.3023927 , -0.03763906],
#        [-0.11005969, -0.5775205 ,  0.14904028, -0.5815603 ,  0.2891342 ,
#          0.24372941, -0.07705129,  0.08671064,  0.3053243 ,  0.22370532],
#        [-0.4305587 , -0.18598466,  0.19982159, -0.02907225, -0.24557789,
#          0.02690537, -0.43406966, -0.45363924, -0.44824028, -0.0937949 ],
#        [ 0.5801653 , -0.44201052,  0.06614203,  0.08535957, -0.4318103 ,
#         -0.36911398, -0.362707  ,  0.11984975,  0.09763527, -0.0705581 ]],
#       dtype=float32)>

# %%
# bias
model.weights[2]
# Out:
# <tf.Variable 'simple_rnn_1/bias:0' shape=(10,) dtype=float32, numpy=
# array([ 1.0906362e-03, -5.2152263e-05,  6.3192967e-04, -6.1487913e-04,
#         3.8400169e-03, -1.4719414e-03,  3.9028833e-03, -2.5122170e-03,
#        -8.0384145e-04, -1.4883890e-03], dtype=float32)>
